# %%
#!pip install mlflow tensorflow scikit-learn pandas matplotlib

# %%
import os
import sys
sys.path.append(os.path.abspath('..')) # add parent path to working directory

# %%
from importlib import reload
from scripts import fraud_detection_dl
reload(fraud_detection_dl) # reload module
# Out:
# <module 'scripts.fraud_detection_dl' from 'c:\\ML and DS Files\\Kifiya AI\\Kaim-week-8-9\\scripts\\fraud_detection_dl.py'>

# %% [markdown]
# #  Merged and Featured Fraud Data Training and Evaluation

# %%
# Import the class
from scripts.fraud_detection_dl import FraudDetectionDL
fraud_dl = FraudDetectionDL()

# %% [markdown]
# # Train and evaluate MLP Model

# %%
mlp_model, mlp_history = fraud_dl.train_and_evaluate(model_type='mlp', dataset_type='fraud', epochs=50)
fraud_dl.plot_training_history(mlp_history, model_type='mlp', dataset_type='fraud')
fraud_dl.evaluate_model(mlp_model, dataset_type='fraud')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025/02/11 08:32:58 WARNING mlflow.tensorflow: Unrecognized dataset type <class 'pandas.core.frame.DataFrame'>. Dataset logging skipped.
# 2025/02/11 08:32:58 WARNING mlflow.tensorflow: Failed to log training dataset information to MLflow Tracking. Reason: 'DataFrame' object has no attribute 'flatten'
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/50
# 1874/1874 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9401 - loss: 0.2221 - val_accuracy: 0.9510 - val_loss: 0.1796
# Epoch 2/50
# ...

# %% [markdown]
# # Train and Evaluate CNN Model

# %%
cnn_model, cnn_history = fraud_dl.train_and_evaluate(model_type='cnn', dataset_type='fraud', epochs=50)
fraud_dl.plot_training_history(cnn_history, model_type='cnn', dataset_type='fraud')
fraud_dl.evaluate_model(cnn_model, dataset_type='fraud')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025/02/11 08:37:11 WARNING mlflow.tensorflow: Unrecognized dataset type <class 'pandas.core.frame.DataFrame'>. Dataset logging skipped.
# 2025/02/11 08:37:11 WARNING mlflow.tensorflow: Failed to log training dataset information to MLflow Tracking. Reason: 'DataFrame' object has no attribute 'flatten'
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/50
# 1874/1874 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9470 - loss: 0.2073 - val_accuracy: 0.9521 - val_loss: 0.1832
# Epoch 2/50
# ...

# %% [markdown]
# # Train and Evaluate RNN Model

# %%
rnn_model, rnn_history = fraud_dl.train_and_evaluate(model_type='rnn', dataset_type='fraud', epochs=50)
fraud_dl.plot_training_history(rnn_history, model_type='rnn', dataset_type='fraud')
fraud_dl.evaluate_model(rnn_model, dataset_type='fraud')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025/02/11 08:41:05 WARNING mlflow.tensorflow: Unrecognized dataset type <class 'pandas.core.frame.DataFrame'>. Dataset logging skipped.
# 2025/02/11 08:41:05 WARNING mlflow.tensorflow: Failed to log training dataset information to MLflow Tracking. Reason: 'DataFrame' object has no attribute 'flatten'
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/50
# 1874/1874 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9146 - loss: 0.2779 - val_accuracy: 0.9530 - val_loss: 0.1896
# Epoch 2/50
# ...

# %% [markdown]
# # Train and Evaluate LSTM Model

# %%
lstm_model, lstm_history = fraud_dl.train_and_evaluate(model_type='lstm', dataset_type='fraud', epochs=50)
fraud_dl.plot_training_history(lstm_history, model_type='lstm', dataset_type='fraud')
fraud_dl.evaluate_model(lstm_model, dataset_type='fraud')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025/02/11 08:49:42 WARNING mlflow.tensorflow: Unrecognized dataset type <class 'pandas.core.frame.DataFrame'>. Dataset logging skipped.
# 2025/02/11 08:49:42 WARNING mlflow.tensorflow: Failed to log training dataset information to MLflow Tracking. Reason: 'DataFrame' object has no attribute 'flatten'
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/50
# 1874/1874 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.9266 - loss: 0.2671 - val_accuracy: 0.9530 - val_loss: 0.1866
# Epoch 2/50
# ...

# %% [markdown]
# # Repeat Training and Evaluation for Credit Card Dataset

# %%
for model_type in ['mlp', 'cnn', 'rnn', 'lstm']:
    model, history = fraud_dl.train_and_evaluate(model_type=model_type, dataset_type='credit', epochs=50)
    fraud_dl.plot_training_history(history, model_type=model_type, dataset_type='credit')
    fraud_dl.evaluate_model(model, dataset_type='credit')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025/02/11 09:02:15 WARNING mlflow.tensorflow: Unrecognized dataset type <class 'pandas.core.frame.DataFrame'>. Dataset logging skipped.
# 2025/02/11 09:02:15 WARNING mlflow.tensorflow: Failed to log training dataset information to MLflow Tracking. Reason: 'DataFrame' object has no attribute 'flatten'
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/50
# 3561/3561 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - accuracy: 0.9983 - loss: 0.0208 - val_accuracy: 0.9993 - val_loss: 0.0036
# Epoch 2/50
# ...
